# %%
import geopandas as gpd 
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('data/merge_1.csv', index_col=0)
df.head()
# Out:
#              Name_x  Patents     Exits  Jobs   Funding  Reporting Year  \
# 0     Hernandez Ltd        2   8000000    61   8000000            2002
# 1  Valentine-Acosta        0   1500000    34   1500000            2014
# 2     Ochoa-Miranda        2  13000000    58  13000000            2003
# 3  Christian-Peters        4   2000000    18  25500000            2001
# 4    Thompson Group        2   5500000    39   2000000            2010
#
#           Name_y   First      Last   Join_Date      Race Gender Sexuality  \
# 0   Bill Sanford    Bill   Sanford  2004-08-18     White      M         H
# 1   Sarah Palmer   Sarah    Palmer  2017-06-06     White      M         H
# 2   Jim Mcdaniel     Jim  Mcdaniel  2009-11-28  Hispanic      F         H
# 3  Ashley Moreno  Ashley    Moreno  2006-08-01  Hispanic      F         H
# 4     Kevin Knox   Kevin      Knox  2021-06-12  Hispanic      F         H
#
#   Transgender Self-Identified
# 0           N             NaN
# 1           N             NaN
# 2           N             NaN
# 3           N             NaN
# 4           N             NaN

# %%
df_2 = pd.read_csv('data/df_info.csv', index_col=0)
df_2.head()
# Out:
#                Name Founding Date                 Industry          Location
# 0     Hernandez Ltd    2002-07-28                  Biotech      Missoula, MT
# 1  Valentine-Acosta    2014-09-05               Food Prod.  Grand Rapids, MI
# 2     Ochoa-Miranda    2003-11-29  Tech Hardware & Storage         Miami, FL
# 3  Christian-Peters    2001-07-21                 Software     Charlotte, NC
# 4    Thompson Group    2010-12-26                eCommerce     St. Louis, MO

# %%
merge_2 = df.merge(df_2, left_on='Name_x', right_on='Name', how='left')
merge_2.head()
# Out:
#              Name_x  Patents     Exits  Jobs   Funding  Reporting Year  \
# 0     Hernandez Ltd        2   8000000    61   8000000            2002
# 1  Valentine-Acosta        0   1500000    34   1500000            2014
# 2     Ochoa-Miranda        2  13000000    58  13000000            2003
# 3  Christian-Peters        4   2000000    18  25500000            2001
# 4    Thompson Group        2   5500000    39   2000000            2010
#
#           Name_y   First      Last   Join_Date      Race Gender Sexuality  \
# 0   Bill Sanford    Bill   Sanford  2004-08-18     White      M         H
# 1   Sarah Palmer   Sarah    Palmer  2017-06-06     White      M         H
# 2   Jim Mcdaniel     Jim  Mcdaniel  2009-11-28  Hispanic      F         H
# 3  Ashley Moreno  Ashley    Moreno  2006-08-01  Hispanic      F         H
# 4     Kevin Knox   Kevin      Knox  2021-06-12  Hispanic      F         H
#
#   Transgender Self-Identified              Name Founding Date  \
# 0           N             NaN     Hernandez Ltd    2002-07-28
# 1           N             NaN  Valentine-Acosta    2014-09-05
# 2           N             NaN     Ochoa-Miranda    2003-11-29
# 3           N             NaN  Christian-Peters    2001-07-21
# 4           N             NaN    Thompson Group    2010-12-26
#
#                   Industry          Location
# 0                  Biotech      Missoula, MT
# 1               Food Prod.  Grand Rapids, MI
# 2  Tech Hardware & Storage         Miami, FL
# 3                 Software     Charlotte, NC
# 4                eCommerce     St. Louis, MO

# %%
merge_2.isna().sum()
# Out:
# Name_x                  0
# Patents                 0
# Exits                   0
# Jobs                    0
# Funding                 0
# Reporting Year          0
# Name_y                  0
# First                   0
# Last                    0
# Join_Date               0
# Race                    0
# Gender                  0
# Sexuality               0
# Transgender             0
# Self-Identified    638329
# Name                    0
# Founding Date           0
# Industry                0
# Location                0
# dtype: int64

# %%
merge_2 = merge_2.replace({'Self-Identified': {np.nan: 'NA'}})
merge_2.isna().sum()
# Out:
# Name_x             0
# Patents            0
# Exits              0
# Jobs               0
# Funding            0
# Reporting Year     0
# Name_y             0
# First              0
# Last               0
# Join_Date          0
# Race               0
# Gender             0
# Sexuality          0
# Transgender        0
# Self-Identified    0
# Name               0
# Founding Date      0
# Industry           0
# Location           0
# dtype: int64

# %%
merge_2.to_csv('data/final.csv')

# %%
data = merge_2.copy()
data.head()
# Out:
#                           Name_x  Patents     Exits  Jobs   Funding  \
# 0                Anderson-Zavala        2   2856173    61   3706173
# 1  Bullock, Gonzalez and Hensley        0   9770578    34  27397794
# 2     Simpson, Hicks and Perkins        2  11762344    58  12612344
# 3                 Byrd-Alexander        4   1362538    18   2212538
# 4       Nunez, Hall and Martinez        2  10542380    39  11392380
#
#    Reporting Year         Name_y   First      Last   Join_Date      Race  \
# 0            2017   Bill Sanford    Bill   Sanford  2004-07-06     White
# 1            2002   Sarah Palmer   Sarah    Palmer  2020-01-10     White
# 2            2005   Jim Mcdaniel     Jim  Mcdaniel  2001-07-31  Hispanic
# 3            2011  Ashley Moreno  Ashley    Moreno  2013-10-08  Hispanic
# 4            2001     Kevin Knox   Kevin      Knox  2015-04-07  Hispanic
#
#   Gender Sexuality Transgender Self-Identified                           Name  \
# 0      M         H           N              NA                Anderson-Zavala
# 1      M         H           N              NA  Bullock, Gonzalez and Hensley
# 2      F         H           N              NA     Simpson, Hicks and Perkins
# 3      F         H           N              NA                 Byrd-Alexander
# 4      F         H           N              NA       Nunez, Hall and Martinez
#
#   Founding Date                 Industry          Location
# 0    2017-08-08                  Biotech      Missoula, MT
# 1    2002-12-12               Food Prod.  Grand Rapids, MI
# 2    2005-10-12  Tech Hardware & Storage         Miami, FL
# 3    2011-10-11                 Software     Charlotte, NC
# 4    2001-12-16                eCommerce     St. Louis, MO

# %%
data.columns
# Out:
# Index(['Name_x', 'Patents', 'Exits', 'Jobs', 'Funding', 'Reporting Year',
#        'Name_y', 'First', 'Last', 'Join_Date', 'Race', 'Gender', 'Sexuality',
#        'Transgender', 'Self-Identified', 'Name', 'Founding Date', 'Industry',
#        'Location'],
#       dtype='object')

# %%
data.columns=['Company', 'Patents', 'Exits', 'Jobs', 'Funding', 'Date',
       'Founder', 'First', 'Last', 'Join Date', 'Race', 'Gender', 'Sexuality',
       'Transgender', 'Self-Identified', 'Name', 'Founding Date', 'Industry',
       'Location']

# %%
data['Date'] = pd.to_datetime(data['Date'], format='%Y')
data.head()
# Out:
#                          Company  Patents     Exits  Jobs   Funding  \
# 0                Anderson-Zavala        2   2856173    61   3706173
# 1  Bullock, Gonzalez and Hensley        0   9770578    34  27397794
# 2     Simpson, Hicks and Perkins        2  11762344    58  12612344
# 3                 Byrd-Alexander        4   1362538    18   2212538
# 4       Nunez, Hall and Martinez        2  10542380    39  11392380
#
#         Date        Founder   First      Last   Join Date      Race Gender  \
# 0 2017-01-01   Bill Sanford    Bill   Sanford  2004-07-06     White      M
# 1 2002-01-01   Sarah Palmer   Sarah    Palmer  2020-01-10     White      M
# 2 2005-01-01   Jim Mcdaniel     Jim  Mcdaniel  2001-07-31  Hispanic      F
# 3 2011-01-01  Ashley Moreno  Ashley    Moreno  2013-10-08  Hispanic      F
# 4 2001-01-01     Kevin Knox   Kevin      Knox  2015-04-07  Hispanic      F
#
#   Sexuality Transgender Self-Identified                           Name  \
# 0         H           N              NA                Anderson-Zavala
# 1         H           N              NA  Bullock, Gonzalez and Hensley
# 2         H           N              NA     Simpson, Hicks and Perkins
# 3         H           N              NA                 Byrd-Alexander
# 4         H           N              NA       Nunez, Hall and Martinez
#
#   Founding Date                 Industry          Location
# 0    2017-08-08                  Biotech      Missoula, MT
# 1    2002-12-12               Food Prod.  Grand Rapids, MI
# 2    2005-10-12  Tech Hardware & Storage         Miami, FL
# 3    2011-10-11                 Software     Charlotte, NC
# 4    2001-12-16                eCommerce     St. Louis, MO

# %%
data.set_index('Date', inplace=True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 718782 entries, 2017-01-01 to 2021-01-01
# Data columns (total 18 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Company          718782 non-null  object
#  1   Patents          718782 non-null  int64
#  2   Exits            718782 non-null  int64
#  3   Jobs             718782 non-null  int64
#  4   Funding          718782 non-null  int64
#  5   Founder          718782 non-null  object
#  6   First            718782 non-null  object
#  7   Last             718782 non-null  object
#  8   Join Date        718782 non-null  object
#  9   Race             718782 non-null  object
#  10  Gender           718782 non-null  object
#  11  Sexuality        718782 non-null  object
#  12  Transgender      718782 non-null  object
#  13  Self-Identified  718782 non-null  object
#  14  Name             718782 non-null  object
#  15  Founding Date    718782 non-null  object
#  16  Industry         718782 non-null  object
#  17  Location         718782 non-null  object
# dtypes: int64(4), object(14)
# memory usage: 104.2+ MB

# %%
funding = data['Funding']
funding.head()
# Out:
# Date
# 2017-01-01     3706173
# 2002-01-01    27397794
# 2005-01-01    12612344
# 2011-01-01     2212538
# 2001-01-01    11392380
# Name: Funding, dtype: int64

# %%
funding_monthly = funding.resample('12M').asfreq()
funding_monthly.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/0f/dj_hz1316w7c4qhdk33w3p3w0000gn/T/ipykernel_12091/1651385097.py in <module>
# ----> 1 funding_monthly = funding.resample('12M').asfreq()
#       2 funding_monthly.head()
#
# ~/opt/anaconda3/envs/geo-env/lib/python3.9/site-packages/pandas/core/resample.py in asfreq(self, fill_value)
#     883         DataFrame.asfreq: Convert TimeSeries to specified frequency.
#     884         """
# --> 885         return self._upsample("asfreq", fill_value=fill_value)
#     886
#     887     def std(self, ddof=1, *args, **kwargs):
#
# ~/opt/anaconda3/envs/geo-env/lib/python3.9/site-packages/pandas/core/resample.py in _upsample(self, method, limit, fill_value)
#    1203             result.index = res_index
#    1204         else:
# -> 1205             result = obj.reindex(
#    1206                 res_index, method=method, limit=limit, fill_value=fill_value
#    1207             )
#
# ~/opt/anaconda3/envs/geo-env/lib/python3.9/site-packages/pandas/core/series.py in reindex(self, index, **kwargs)
#    4578     )
#    4579     def reindex(self, index=None, **kwargs):
# -> 4580         return super().reindex(index=index, **kwargs)
#    4581
#    4582     @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#
# ~/opt/anaconda3/envs/geo-env/lib/python3.9/site-packages/pandas/core/generic.py in reindex(self, *args, **kwargs)
#    4816
#    4817         # perform the reindex on the axes
# -> 4818         return self._reindex_axes(
#    4819             axes, level, limit, tolerance, method, fill_value, copy
#    4820         ).__finalize__(self, method="reindex")
#
# ~/opt/anaconda3/envs/geo-env/lib/python3.9/site-packages/pandas/core/generic.py in _reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    4837
#    4838             axis = self._get_axis_number(a)
# -> 4839             obj = obj._reindex_with_indexers(
#    4840                 {axis: [new_index, indexer]},
#    4841                 fill_value=fill_value,
#
# ~/opt/anaconda3/envs/geo-env/lib/python3.9/site-packages/pandas/core/generic.py in _reindex_with_indexers(self, reindexers, fill_value, copy, allow_dups)
#    4881
#    4882             # TODO: speed up on homogeneous DataFrame objects
# -> 4883             new_data = new_data.reindex_indexer(
#    4884                 index,
#    4885                 indexer,
#
# ~/opt/anaconda3/envs/geo-env/lib/python3.9/site-packages/pandas/core/internals/managers.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, consolidate, only_slice)
#     668         # some axes don't allow reindexing with dups
#     669         if not allow_dups:
# --> 670             self.axes[axis]._validate_can_reindex(indexer)
#     671
#     672         if axis >= self.ndim:
#
# ~/opt/anaconda3/envs/geo-env/lib/python3.9/site-packages/pandas/core/indexes/base.py in _validate_can_reindex(self, indexer)
#    3783         # trying to reindex on an axis with duplicates
#    3784         if not self._index_as_unique and len(indexer):
# -> 3785             raise ValueError("cannot reindex from a duplicate axis")
#    3786
#    3787     def reindex(
#
# ValueError: cannot reindex from a duplicate axis

# %%
funding.plot(figsize=(16,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
funding.plot(figsize=(16,6), style='.b')
# Out:
# <AxesSubplot:xlabel='Date'>
